# %%
import utils_essentia as ue
import matplotlib.pyplot as plt
import numpy as np

# %%
params=ue.AnalysisParams(1024,261,'hann',2048,22500)

# %%
pitchArray, pitchMelodia, vibFreq, vibExtend = ue.ExtractVocalFeatures('data/normal_mic_mono.wav',params)
zeroCrossingRateArray, energyArray, instantPowerArray, rmsArray, fluxArray = ue.ExtractResidualFeatures('data/normal_mic_mono_residual.wav',params)

# %%
% matplotlib notebook
plt.plot(energyArray)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.save('residual_zcrPlot.npy', zeroCrossingRateArray)
np.save('residual_energyPlot.npy', energyArray)
